# %%
import gensim

word2vec_model = gensim.models.KeyedVectors.load_word2vec_format("./models/180/model.bin", binary=True)

# %%
len(word2vec_model.vectors)

# %%
word2vec_model["пешеход_NOUN"]

# %%
word2vec_model.similarity("пешеход_NOUN", "дорога_NOUN")

# %%
word2vec_model.similarity("дверь_NOUN", "светофор_NOUN")

# %%
word2vec_model.similarity("скользко_ADV", "мороз_NOUN")

# %%
word2vec_model.similarity("самолет_NOUN", "летать_VERB")

# %%
word2vec_model.similarity("самолет_NOUN", "плыть_VERB")
