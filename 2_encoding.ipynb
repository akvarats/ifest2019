# %%
import copy
from collections import defaultdict
from tools import get_corpus, prepare_corpus

# %%
corpus = prepare_corpus(get_corpus())

corpus

# %%
lexicon = sorted(list(set([w for d in corpus for w in d])))
lexicon

# %%
features = defaultdict(int)
for token in corpus[0]:
    features[token] += 1
    
dict(features)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from nltk.text import TextCollection

texts = TextCollection(corpus)

for doc in corpus:
    print({term: texts.tf_idf(term, doc) for term in doc})
    print("")
